# %%
library(tidyverse)
library(gridExtra)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# √ ggplot2 2.2.1     √ purrr   0.2.4
# √ tibble  1.4.1     √ dplyr   0.7.4
# √ tidyr   0.7.2     √ stringr 1.2.0
# √ readr   1.1.1     √ forcats 0.2.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
smaller = diamonds  %>% filter(carat <3)

# %%
smaller  %>% ggplot(aes(x=carat)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
smaller  %>% ggplot(aes(x=carat, color =cut )) + geom_freqpoly()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
diamonds  %>% ggplot(aes(x = y), binwidth = 0.5) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
diamonds  %>% ggplot(aes(x = y), binwidth = 0.5) + geom_histogram() + coord_cartesian(ylim = c(0,50))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# #### 5.4 결측값

# %%
diamonds2 <- diamonds  %>% filter(between(y, 3, 20))

# %%
diamonds3 = diamonds  %>% mutate(y = ifelse(y < 3 | y >20, NA, y))

# %%
diamonds3  %>% ggplot(aes(x = x, y = y)) + geom_point()
# Out:
# Warning message:
# "Removed 9 rows containing missing values (geom_point)."
# plot without title

# %%
diamonds3  %>% ggplot(aes(x = x, y = y)) + geom_point(na.rm = T)
# Out:
# plot without title

# %%
diamonds  %>% ggplot(aes(x = price, y = ..density..)) + 
    geom_freqpoly(aes(color = cut), binwidth = 500)
# Out:
# plot without title

# %%
diamonds  %>% ggplot(aes(x= cut, y = price)) + geom_boxplot() + 
    coord_cartesian(ylim = c(0, 10000))
# Out:
# plot without title

# %%
mpg  %>% ggplot(aes(x = reorder(class, hwy, FUN = median), y = hwy)) + 
    geom_boxplot()  + labs(x = "class") + coord_flip()
# Out:
# plot without title

# %%
diamonds  %>% count(color, cut)  %>% ggplot(aes(x= color, cut, fill = n)) + geom_tile()
# Out:
# plot without title

# %%
smaller  %>% ggplot(aes(x = carat, y = price)) + geom_bin2d()
# Out:
# plot without title

# %%
smaller  %>% ggplot(aes(x = carat, y = price)) + 
    geom_boxplot(aes(group = cut_width(carat, 0.5)))
# Out:
# plot without title

# %%
smaller  %>% ggplot(aes(x = carat, y = price)) + 
    geom_boxplot(aes(group = cut_width(carat, 0.5)), varwidth = T)
# Out:
# plot without title

# %%
smaller  %>% ggplot(aes(x = carat, y = price)) + 
    geom_boxplot(aes(group = cut_number(carat, 20)))
# Out:
# plot without title
