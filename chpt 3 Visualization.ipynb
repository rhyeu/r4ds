# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# √ ggplot2 2.2.1     √ purrr   0.2.4
# √ tibble  1.4.1     √ dplyr   0.7.4
# √ tidyr   0.7.2     √ stringr 1.2.0
# √ readr   1.1.1     √ forcats 0.2.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# ### mpg data 시각화

# %%
mpg  %>% ggplot(aes(x = displ, y = hwy)) + geom_point()
# mpg  %>% ggplot() + geom_point(aes(x = displ, y = hwy)) aes는 어디에 하는지 상관 없는 듯
# Out:
# plot without title

# %%
# 도움말 
# help(mpg)
# ?mpg

# %%
mpg  %>%  ggplot(aes(x = hwy, y = cyl)) + geom_point()
# Out:
# plot without title

# %%
mpg  %>%  ggplot(aes(x = class, y = drv)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ### 1.3 심미성 매핑

# %%
mpg %>% ggplot(aes(x = displ, y = hwy, color = class )) + geom_point()
# Out:
# plot without title

# %%
mpg  %>% ggplot() + geom_point(aes(x = displ, y = hwy, size = class))
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title

# %%
mpg  %>% ggplot() + geom_point(aes(x = displ, y = hwy, alpha = class))
# Out:
# plot without title

# %%
mpg  %>% ggplot() + geom_point(aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# "The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them."Warning message:
# "Removed 62 rows containing missing values (geom_point)."
# plot without title

# %%
# 이렇게 하면 안 됨, aes 바깥에 해야!
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy, color = "blue" ))
# Out:
# plot without title

# %%
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy ), color = "blue")
# Out:
# plot without title

# %%
### 모양(shape), 점 굵기, 사이즈 지정

mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy ), 
                              color = "white", stroke = 2)
# Out:
# plot without title

# %%
str(mpg)
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	234 obs. of  11 variables:
#  $ manufacturer: chr  "audi" "audi" "audi" "audi" ...
#  $ model       : chr  "a4" "a4" "a4" "a4" ...
#  $ displ       : num  1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int  1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int  4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr  "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr  "f" "f" "f" "f" ...
#  $ cty         : int  18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int  29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr  "p" "p" "p" "p" ...
#  $ class       : chr  "compact" "compact" "compact" "compact" ...

# %%
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy, color = year))
# Out:
# plot without title

# %% [markdown]
# ### 1.5 facet - 주의

# %%
#### 하나의 변수에 대해 분할
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy)) +
    facet_wrap(~ class, ncol = 4)
# Out:
# plot without title

# %%
#### 두 변수에 대해 분할
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy)) +
    facet_grid(cyl~drv)
# Out:
# plot without title

# %%
#### 두 변수에 대해 분할
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy)) +
    facet_grid(.~ cyl)
# Out:
# plot without title

# %%
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy)) +
    facet_wrap(~ cyl, nrow = 1)
# Out:
# plot without title

# %%
#### 두 변수에 대해 분할
mpg %>% ggplot() + geom_point(aes(x = displ, y = hwy)) +
    facet_grid(drv ~ .)
# Out:
# plot without title

# %%
#### 연속형 변수로 면 분할하면 안 좋음.
mpg %>% ggplot() + geom_point(aes(x = year, y = hwy)) +
    facet_wrap( ~ displ)
# Out:
# plot without title

# %%
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	234 obs. of  11 variables:
#  $ manufacturer: chr  "audi" "audi" "audi" "audi" ...
#  $ model       : chr  "a4" "a4" "a4" "a4" ...
#  $ displ       : num  1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int  1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int  4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr  "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr  "f" "f" "f" "f" ...
#  $ cty         : int  18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int  29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr  "p" "p" "p" "p" ...
#  $ class       : chr  "compact" "compact" "compact" "compact" ...

# %%
mpg  %>% ggplot(aes(x = displ, y = hwy)) +geom_point()+ facet_grid(drv~.)
# Out:
# plot without title

# %%
mpg  %>% ggplot(aes(x = displ, y = hwy)) +geom_point()+ facet_grid(.~cyl)
# Out:
# plot without title

# %%
mpg  %>% ggplot(aes(x = displ, y = hwy)) + geom_point()+
    facet_wrap(~class, nrow = 2)
# Out:
# plot without title

# %%
mpg  %>%  ggplot(aes(x = displ, y = hwy, color = class)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ### 1.6 기하객체 - 중요
# - 참고 ggplot 치트시트

# %%
mpg  %>%  ggplot() + geom_point(aes(x= displ, y = hwy))
# Out:
# plot without title

# %%
mpg  %>%  ggplot() + geom_smooth(aes(x= displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
mpg  %>%  ggplot() + geom_smooth(aes(x= displ, y = hwy, linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
mpg  %>%  ggplot(aes(x = displ, y = hwy, color = drv)) + 
    geom_point() + geom_smooth(aes(linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
mpg  %>%  ggplot(aes(x = displ, y = hwy, group = drv)) + 
    geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
mpg  %>%  ggplot(aes(x = displ, y = hwy, group = drv)) + 
    geom_smooth(aes(color = drv),
               show.legend = F)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
mpg  %>% ggplot(aes(x = displ, y = hwy)) + 
    geom_point(aes(color = class)) + 
    geom_smooth( data = mpg %>% filter(class == "subcompact"),
               se = F)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
mpg  %>% ggplot(aes(x= displ, y = hwy, color = drv)) + 
    geom_point() + geom_smooth(se = F)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
### 1.6.1 연습문제 6
####  키포인트 : 6번째 플롯을 그리기 위해서는 점의 shape를 바꿔야함
library(grid)
library(gridExtra)
# Out:
# Attaching package: 'gridExtra'
#
# The following object is masked from 'package:dplyr':
#
#     combine

# %%
p1 = mpg  %>% ggplot(aes(x = displ, y = hwy)) +
  geom_point() + geom_smooth( se = F)

p2 = mpg  %>% ggplot(aes(x = displ, y = hwy)) +
  geom_point() + geom_smooth(aes(group = drv),se = F)

p3 = mpg  %>% ggplot(aes(x = displ, y = hwy, color = drv)) +
  geom_point() + geom_smooth(se = F)

p4 = mpg  %>% ggplot(aes(x = displ, y = hwy)) +
  geom_point(aes(color = drv)) + geom_smooth(se = F)
p5 = mpg  %>% ggplot(aes(x= displ, y = hwy)) + 
  geom_point(aes(color = drv)) + geom_smooth(aes(linetype = drv), se = F)

p6 = mpg  %>% ggplot(aes(x = displ, y = hwy)) + geom_point(aes(fill= drv), 
                                                           stroke = 1, color = "white", shape = 21)

grid.arrange(p1,p2,p3,p4,p5,p6, ncol = 2)
# Out:
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# `geom_smooth()` using method = 'loess'
# plot without title

# %% [markdown]
# ### 1.7 통계적 변환

# %%
data(diamonds)

# %%
diamonds  %>% ggplot(aes(x = cut)) + geom_bar()
# Out:
# plot without title

# %%
### 위와 동일
diamonds  %>% ggplot(aes(x = cut)) + stat_count()
# Out:
# plot without title

# %%
diamonds  %>% ggplot(aes(x= cut, y = ..prop.., group = 1)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# ### 신기

# %%
diamonds  %>% ggplot(aes(x = cut, y = depth)) + stat_summary(
fun.ymin = min,
fun.ymax = max,
fun.y = median)
# Out:
# plot without title

# %% [markdown]
# ### 2변수 히스토그램 : geom_col

# %%
diamonds  %>% ggplot(aes(x = cut, y = depth)) + geom_col()
# Out:
# plot without title

# %% [markdown]
# ### 1.8 위치조정

# %%
diamonds  %>% ggplot(aes ( x= cut, color = cut)) + geom_bar()
# Out:
# Warning message:
# "position_stack requires non-overlapping x intervals"
# plot without title

# %%
diamonds  %>% ggplot(aes ( x= cut, fill = cut)) + geom_bar()
# Out:
# plot without title

# %%
diamonds  %>% ggplot(aes ( x= cut, fill = clarity)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# ### 누적 막대 말고

# %%
diamonds  %>% ggplot(aes ( x= cut, fill = clarity)) + 
geom_bar(alpha = 0.5, position = "identity")
# Out:
# plot without title

# %%
### 비율 비교
diamonds  %>% ggplot(aes ( x= cut, fill = clarity)) + 
geom_bar(alpha = 0.5, position = "fill")
# Out:
# plot without title

# %%
diamonds  %>% ggplot(aes ( x= cut, fill = clarity)) + 
geom_bar(alpha = 0.8, position = "dodge")
# Out:
# plot without title

# %% [markdown]
# ### Scatter plot에서 노이즈 추가해서 시각화 강화 - 겹치지 않게

# %%
p1 = mpg  %>%  ggplot(aes(x= displ,  y = hwy)) + geom_point()
p2 = mpg  %>%  ggplot(aes(x= displ,  y = hwy)) + geom_point(position = "jitter")

grid.arrange(p1, p2)
# Out:
# plot without title

# %% [markdown]
# #### 연습문제

# %%
mpg  %>% ggplot(aes(x = cty, y = hwy)) + geom_point(position = "jitter")
# Out:
# plot without title

# %%
### 상대적 크기 비교
mpg  %>% ggplot(aes(x = cty, y = hwy)) + geom_count()
# Out:
# plot without title

# %%
mpg  %>% ggplot(aes(x = drv, y = hwy, color = drv)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# ### 1.9 좌표계

# %%
p1 = mpg  %>% ggplot(aes(x = class, y = hwy)) + geom_boxplot()
p2 = mpg  %>% ggplot(aes(x = class, y = hwy)) + geom_boxplot() + coord_flip()

grid.arrange(p1, p2)
# Out:
# plot without title

# %%
nz = map_data("nz")
nz  %>%  ggplot(aes(long, lat, group = group)) + 
    geom_polygon(fill = "white", color = "black") +
    coord_quickmap()
# Out:
# plot without title

# %%
bar <- ggplot(data = diamonds) + 
  geom_bar(
    mapping = aes(x = cut, fill = cut), 
    show.legend = FALSE,
    width = 1
  ) + 
#  theme(aspect.ratio = 1) +
  labs(x = NULL, y = NULL)
bar + coord_flip() + coord_polar()
# Out:
# plot without title
